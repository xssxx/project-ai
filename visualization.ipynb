# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
organic = pd.read_csv('datasets/Organic.csv')
conventional = pd.read_csv('datasets/Conventional.csv')
brazil = pd.read_csv('datasets/Brazil.csv')

# %%
brazil.iloc[:, 1:].corr()
# Out:
#           Envi      Fuji      Gala      type
# Envi  1.000000  0.839518  0.786584 -0.942218
# Fuji  0.839518  1.000000  0.673426 -0.877933
# Gala  0.786584  0.673426  1.000000 -0.824721
# type -0.942218 -0.877933 -0.824721  1.000000

# %%
organic.iloc[:, 1:].corr()
# Out:
#           Envi      Fuji      Gala
# Envi  1.000000  0.754925  0.316384
# Fuji  0.754925  1.000000  0.266969
# Gala  0.316384  0.266969  1.000000

# %%
conventional.iloc[:, 1:].corr()
# Out:
#           Envi      Fuji      Gala
# Envi  1.000000  0.064609  0.052876
# Fuji  0.064609  1.000000 -0.187454
# Gala  0.052876 -0.187454  1.000000

# %%
brazil.hist(); # right skewed

# %%
sns.kdeplot(data=brazil, x='Envi');
sns.kdeplot(data=brazil, x='Fuji');
sns.kdeplot(data=brazil, x='Gala');

# %%
sns.boxplot(data=brazil.drop(columns='type'))
# Out:
# <Axes: >
